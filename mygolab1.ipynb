# %% [markdown]
# <a href="https://colab.research.google.com/github/shiluan/PowerBI-CSharp/blob/master/mygolab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('welcome my golab!!!')
# Out:
# welcome my golab!!!

# %%
message = 'A Great Tutorial on Colab by Tutorialspoint!!'
greeting = !echo -e '$message\n$message'
greeting
# Out:
# ['A Great Tutorial on Colab by Tutorialspoint!!',
#  'A Great Tutorial on Colab by Tutorialspoint!!']

# %%
import numpy as np
from matplotlib import pyplot as plt

y = np.random.randn(100)
x = [x for x in range(len(y))]

plt.plot(x, y, '-')
plt.fill_between(x, y, 200, where = (y > 195), facecolor='g', alpha=0.6)

plt.title("Sample Plot")
plt.show()
